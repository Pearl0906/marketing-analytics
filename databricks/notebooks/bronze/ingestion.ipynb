# %%
# %sql
CREATE OR REPLACE TABLE marketing.bronze.customers
AS
SELECT *
FROM read_files(
  '/Volumes/marketing/bronze/raw_data/customers.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);
